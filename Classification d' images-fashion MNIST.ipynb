# %%
from tensorflow.keras.datasets.fashion_mnist import load_data
(x_train , y_train) , (x_test , y_test) = load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
def mlp(input_dim , output_dim):
  model = Sequential()
  coucheEntree = Dense(100,activation='sigmoid',input_dim=28*28 )
  coucheIntermediaire = Dense(200, activation='tanh')
  coucheSortie = Dense(10, activation='softmax')
  model.add(coucheEntree)
  model.add(coucheIntermediaire)
  model.add(coucheSortie)
  return model

# %%
mlp(784,10)

# %%
model_mlp.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cb7f357e4bda> in <module>()
# ----> 1 model.mlp.summary()
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras import Seq
